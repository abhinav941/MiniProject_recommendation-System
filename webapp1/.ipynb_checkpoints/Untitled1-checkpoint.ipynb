# %%
import pandas as pd
df = pd.read_csv('movie_data.csv')
df['rating']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rating'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-804f4266725c> in <module>()
#       1 import pandas as pd
# ...

# %%
df.to_csv('genre.csv')

# %%
df1 = pd.read_csv('movies_data.csv',names=['id','language','movie','description','image','date','status','rating','votecount','genre1'])

# %%
df1
# Out:
#           id language                              movie  \
# 0          0       en                          Toy Story
# 1          1       en                            Jumanji
# 2          2       en                   Grumpier Old Men
# 3          3       en                  Waiting to Exhale
# 4          4       en        Father of the Bride Part II
# 5          5       en                               Heat
# 6          6       en                            Sabrina
# 7          7       en                       Tom and Huck
# 8          8       en                       Sudden Death
# 9          9       en                          GoldenEye
# 10        10       en             The American President
# 11        11       en        Dracula: Dead and Loving It
# 12        12       en                              Balto
# 13        13       en                              Nixon
# 14        14       en                   Cutthroat Island
# ...

# %%
df
# Out:
#             id1     genre1           genre2           genre3    genre4  \
# NaN         NaN     genre1           genre2           genre3    genre4
# NaN          id     genre1           genre2           genre3    genre4
#  0.0         id     genre1           genre2           genre3    genre4
#  1.0          0  Animation           Comedy           Family       NaN
#  2.0          1  Adventure          Fantasy           Family       NaN
#  3.0          2    Romance           Comedy              NaN       NaN
#  4.0          3     Comedy            Drama          Romance       NaN
#  5.0          4  Comedy                 NaN              NaN       NaN
#  6.0          5     Action            Crime            Drama  Thriller
#  7.0          6     Comedy          Romance              NaN       NaN
#  8.0          7     Action        Adventure            Drama    Family
#  9.0          8     Action        Adventure         Thriller       NaN
# ...

# %%
df
# Out:
#          A        B      C          D              genres
# 0  Austria  Germany   Test  Australia  (g, e, n, r, e, s)
# 1    Spain   France  Italy     Mexico  (g, e, n, r, e, s)
